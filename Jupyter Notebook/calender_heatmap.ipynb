# %%
import numpy as np
import pandas as pd
# import calmap
import matplotlib.pyplot as plt
import matplotlib.font_manager
import calplot
# import cv2


data = pd.read_csv('C:/Users/jyoti/Downloads/donneestrafic-2018.csv')
data['DATECOM'] = pd.to_datetime(data['DATECOM'])
data.set_index('DATECOM', inplace=True)
data =  data[data.DIRECTION == 3]
data = data[data.VEHICULE == 'C']
data = data[data.ROUTE == 'A1']
# print(data)
pil = calplot.calplot(data = data['SUM_TRAF'], cmap = 'GnBu', dropzero = True, suptitle = "Total cars in morning rush hours each day", figsize -  )
plt.savefig('test.jpg')
# plt.show(pil)
# cv2.imwrite('trdt.jpg', pil)
# print(pl1)
# calmap.yearplot(data.MORNING_HOURS, year=2020)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-33a1bae0e999> in <module>
#      15 data = data[data.ROUTE == 'A1']
#      16 # print(data)
# ---> 17 pil = calplot.calplot(data = data['SUM_TRAF'], cmap = 'GnBu', dropzero = True, suptitle = "Total cars in morning rush hours each day", dpi = 150)
#      18 plt.savefig('test.jpg')
#      19 # plt.show(pil)
#
# ~\anaconda3\lib\site-packages\calplot\calplot.py in calplot(data, how, yearlabels, yearascending, yearlabel_kws, subplot_kws, gridspec_kws, figsize, fig_kws, colorbar, suptitle, suptitle_kws, tight_layout, **kwargs)
#     318
#     319     for year, ax in zip(years, axes):
# --> 320         yearplot(by_day, year=year, how=None, ax=ax, **kwargs)
#     321         max_weeks = max(max_weeks, ax.get_xlim()[1])
#     322
#
# ...
